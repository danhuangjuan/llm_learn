# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("DEEPSEEK_API_KEY")
base_url = os.getenv("DEEPSEEK_BASE_URL")
model = "deepseek-chat"

prompt = "完成下列句子：很久很久以前，有一个"
messages = [{"role": "user", "content": prompt}]

client = OpenAI(api_key=api_key, base_url=base_url)
response = client.chat.completions.create(
    model=model,
    messages=messages,
    max_tokens=1024
)
print(response.choices[0].message.content)
# Out:
# 很久很久以前，有一个**古老的王国，隐藏在云雾缭绕的群山之间。王国里住着一位喜欢仰望星空的小公主，她总相信每颗星星里都藏着一个未讲完的故事。**

# %% [markdown]
# ## 练习 - 构建一个食谱生成器
#
# 现在我们已经演示了一个场景，接下来让我们编写代码来实现这个场景。请按照以下步骤操作：
#
# 1. 以现有的 *app.py* 文件为起点
# 1. 找到 `prompt` 变量，并将其代码更改为以下内容：

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("DEEPSEEK_API_KEY")
base_url = os.getenv("DEEPSEEK_BASE_URL")
model = "deepseek-chat"

prompt = "Show me 5 recipes for a dish with the following ingredients: chicken, potatoes, and carrots. Per recipe, list all the ingredients used"
messages = [{"role": "user", "content": prompt}]

client = OpenAI(api_key=api_key, base_url=base_url)
completion = client.chat.completions.create(model=model, messages=messages, max_tokens=600)

print(completion.choices[0].message.content)
# Out:
# Of course! Here are 5 distinct recipes using chicken, potatoes, and carrots as the core ingredients. Each recipe includes a full ingredient list.
#
# ### 1. Classic One-Pan Roasted Chicken and Vegetables
# A simple, hands-off dish where everything roasts together for deep, caramelized flavors.
# *   **Ingredients:**
#     *   4 bone-in, skin-on chicken thighs or drumsticks
#     *   1 lb (450g) baby potatoes, halved
#     *   3 large carrots, peeled and cut into 1-inch chunks
#     *   1 onion, cut into wedges
#     *   3 tbsp olive oil
#     *   4 cloves garlic, minced
#     *   1 tsp dried thyme (or rosemary)
#     *   Salt and black pepper to taste
#     *   Fresh parsley, chopped (for garnish)
#
# ### 2. Hearty Chicken, Potato, and Carrot Stew
# A comforting and nourishing stew, perfect for a chilly day.
# *   **Ingredients:**
#     *   1 lb (450g) boneless, skinless chicken thighs, cut into chunks
#     *   3 medium potatoes, peeled and diced into 1-inch cubes
#     *   3 carrots, peeled and sliced into thick rounds
#     *   1 onion, diced
#     *   2 stalks celery, diced
#     *   4 cups chicken broth
#     *   2 tbsp tomato paste
#     *   3 cloves garlic, minced
#     *   2 bay leaves
#     *   1 tsp dried thyme
#     *   2 tbsp all-purpose flour (for thickening)
#     *   2 tbsp olive oil
#     *   Salt and black pepper to taste
#     *   Fresh parsley, chopped (for garnish)
#
# ### 3. Creamy Chicken and Vegetable Pot Pie Filling
# A rich, savory filling that can be topped with puff pastry, biscuits, or served over mashed potatoes.
# *   **Ingredients:**
#     *   2 cups cooked chicken, shredded or diced
#     *   2 medium potatoes, peeled and diced into ½-inch cubes
#     *   2 carrots, peeled and diced into ½-inch cubes
#     *   1/2 cup frozen peas
#     *   1/3 cup unsalted butter
#     *   1/3 cup all-purpose flour
#     *   1/3 cup diced onion
#     *   1/3 cup diced celery
#     *   1 3/4 cups chicken broth
#     *   2/3 cup milk or cream
#     *   1 tsp dried thyme
#     *   Salt and black pepper to taste
#     *   (Optional) 1 sheet puff pastry, for topping
#
# ### 4. Sheet Pan Chicken Fajitas with Potato & Carrot Fries
# A fun twist on fajitas, with spiced potatoes and carrots serving as the "fries" alongside the chicken.
# *   **Ingredients:**
#     *   1
